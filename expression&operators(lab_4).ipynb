# %%
n=9
print(n,'binary',format(n,'b'))
print(n,'*2=',n<<1,format(n<<1,'b'))
print(n,'/2',n>>1,format(n>>1,'b'))
# Out:
# 9 binary 1001
# 9 *2= 18 10010
# 9 /2 4 100

# %%
x=True
y=False
print('x and y is',x and y)
print('x or y is',x or y)
print('not x is',not x)
print('x and y is',x&y)
# Out:
# x and y is False
# x or y is True
# not x is False
# x and y is False

# %%
x=12
y=4
print(x & y)
print(x | y)
print(x ^ y)
# Out:
# 4
# 12
# 8

# %%
x= 'hello world'
print('h' in x)
print('H'not in x)
print('H' in x)
# Out:
# True
# True
# False

# %%
import cmath
a =complex(20+5j)
b= complex(5+3j)
print('a+b',a+b)
print('a-b',a-b)
print('a*b',a*b)
print('a/b',a/b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)
# a/b (3.3823529411764706-1.0294117647058825j)

# %%
import math
a = int(input("side 1: "))
b = int(input("side 2: "))
c = int(input("side 3: "))
s = (a + b + c) / 2
area = math.sqrt(s * (s - a) * (s - b) * (s - c))
print('area of triangle', area)
# Out:
# side 1: 4
# side 2: 5
# side 3: 6
# area of triangle 9.921567416492215

# %%
ch = input("Enter a character: ")
ch=ch.lower()
if(ch=='a'or ch=='e'or ch=='i'or ch=='o'or ch=='u'):
    print(ch, "is a vowel")
else:
    print(ch, "is a consonant")
# Out:
# Enter a character: K
# k is a consonant

# %%
ch=input("enter a character: ")
if(ch.islower()):
    print("character is lower case")
else:
    print("character is upper case")
# Out:
# enter a character: A
# character is upper case

# %%
n=int(input("enter a number:"))
for i in range(1,11):
  print(n,"x",i,"=",n*i)
# Out:
# enter a number:4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
n = int(input("Enter number: "))
fact = 1
sum = 0
for i in range(1, n + 1):
    fact *= i
    sum += fact
print(sum)
# Out:
# Enter number: 4
# 33

# %%
max_num=0
while True:
    num = int(input("Enter number: "))
    if num > max_num:
        max_num = num
    ch = input("More? (y/n): ")
    if ch == 'n':
        break
print("Max =", max_num)
# Out:
# Enter number: 4
# More? (y/n): y
# Enter number: 56
# More? (y/n): y
# Enter number: 3
# More? (y/n): n
# Max = 56

# %%
class Car:
  # constructor (__init__ method)
  def __init__(self, name, model, year):
    self.name = name
    self.model = model
    self.year = year
  def display(self):
    print(f"Car: {self.name} {self.model} ({self.year})")
car1 = Car("Toyota", "Corolla", 2023)
car2 = Car("Tesla", "Model S", 2020)
car1.display()
car2.display()
# Out:
# Car: Toyota Corolla (2023)
# Car: Tesla Model S (2020)

# %%
class Employee:
  def __init__(self, name, salary):
    self.name = name
    self.salary = salary
  def display(self):
    print(self.name, self.salary)
e1 = Employee("ABC", 10000)
e2 = Employee("XYZ", 20000)
e1.display()
e2.display()
# Out:
# ABC 10000
# XYZ 20000

# %%
class Student:
  def __init__(self, name, age, rollno):
    self.name = name
    self.age = age
    self.rollno = rollno

  def display(self):
    print(f"Name: {self.name}, Age: {self.age}, Roll No: {self.rollno}")
s1 = Student("Krati", 20, 101)
s2 = Student("Ishika", 21, 102)
s1.display()
s2.display()
# Out:
# Name: Krati, Age: 20, Roll No: 101
# Name: Ishika, Age: 21, Roll No: 102

# %%
class Employee:
  def __init__(self, name, salary):
    self.name = name
    self.salary = salary
employees = {
  101: Employee("John", 50000),
  102: Employee("Jane", 60000),
  103: Employee("Bob", 55000)
}
for emp_id, emp in employees.items():
  print(f"{emp_id}, {emp.name}, {emp.salary}")
# Out:
# 101, John, 50000
# 102, Jane, 60000
# 103, Bob, 55000
